# %%
import herramientas_de_analisis_de_resultados as h
import numpy as np

# %%
p,v,mr,dt = h.cambio_a_pandas(r"C:\Users\rodri\Documents\Proyectos_Personales\choques\optimizado\dinamica.txt", 800)

# %%
p[(p['t'].isin([i for i in range(0,300)])) & (p['idx'].isin([89]))].plot.scatter(x = 'x', y='y')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
p[(p['t'].isin([232,233,234,235])) & (p['idx'].isin([89]))].plot.scatter(x = 'x', y='y')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
p[(p['t'].isin([i for i in range(0,100)])) & (p['idx'].isin([i for i in range(100)]))].plot.scatter(x = 'x', y='y')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
p[np.abs(p['idx'])==89]
# Out:
#         idx           x         y    t
# 89       89 -390.000000 -1.000000    0
# 889      89 -389.998990 -1.055556    1
# 1689     89 -389.997980 -1.111111    2
# 2489     89 -389.996970 -1.166667    3
# 3289     89 -389.995960 -1.222222    4
# ...     ...         ...       ...  ...
# 796091   89 -385.774840  4.130643  995
# 796891   89 -385.873309  4.209484  996
# 797691   89 -385.971779  4.288325  997
# 798491   89 -386.070249  4.367166  998
# 799291   89 -386.168719  4.446007  999
#
# [1000 rows x 4 columns]

# %%
p[np.abs(p['x'])>=560]
# Out:
# Empty DataFrame
# Columns: [idx, x, y, t]
# Index: []

# %%
p[np.abs(p['y'])>=7]
# Out:
# Empty DataFrame
# Columns: [idx, x, y, t]
# Index: []

# %%
p[p['idx']==0]
# Out:
#         idx           x         y    t
# 0         0 -500.000000 -2.000000    0
# 800       0 -500.079798 -2.035354    1
# 1600      0 -500.159596 -2.070707    2
# 2400      0 -500.239394 -2.106061    3
# 3200      0 -500.319192 -2.141414    4
# ...     ...         ...       ...  ...
# 796002    0 -551.104265 -1.116091  995
# 796802    0 -551.252306 -1.191447  996
# 797602    0 -551.400348 -1.266804  997
# 798402    0 -551.548390 -1.342160  998
# 799202    0 -551.696432 -1.417516  999
#
# [1000 rows x 4 columns]

# %%
len(mr['idx'].unique())
# Out:
# 800

# %%
mr
# Out:
#      idx    m    r
# 0      0  1.0  0.3
# 1      1  1.0  0.3
# 2      2  1.0  0.3
# 3      3  1.0  0.3
# 4      4  1.0  0.3
# ..   ...  ...  ...
# 795  795  1.0  0.3
# 796  796  1.0  0.3
# 797  797  1.0  0.3
# 798  798  1.0  0.3
# 799  799  1.0  0.3
#
# [800 rows x 3 columns]

# %%
v["magv"] = np.sqrt(v['vx']**2 + v['vy']**2)

# %%
v[v['t'] == 0].hist('magv', bins = 40)
# Out:
# array([[<AxesSubplot:title={'center':'magv'}>]], dtype=object)

# %%
v[v['t'] == 50].hist('magv', bins = 40)
# Out:
# array([[<AxesSubplot:title={'center':'magv'}>]], dtype=object)

# %%
v[v['t'] == 100].hist('magv', bins = 40)
# Out:
# array([[<AxesSubplot:title={'center':'magv'}>]], dtype=object)

# %%
v[v['t'] == 150].hist('magv', bins = 40)
# Out:
# array([[<AxesSubplot:title={'center':'magv'}>]], dtype=object)

# %%
v[v['t'] == 200].hist('magv', bins = 40)
# Out:
# array([[<AxesSubplot:title={'center':'magv'}>]], dtype=object)

# %%
v[v['t'] == 250].hist('magv', bins = 30)
# Out:
# array([[<AxesSubplot:title={'center':'magv'}>]], dtype=object)

# %%
v[v['t'] == 799].hist('magv', bins =40)
# Out:
# array([[<AxesSubplot:title={'center':'magv'}>]], dtype=object)

# %%
p[p['idx'].isin([0,800,1,2,3,45,56,78,99])].plot.scatter(x = 't', y = 'y')
# Out:
# <AxesSubplot:xlabel='t', ylabel='y'>
