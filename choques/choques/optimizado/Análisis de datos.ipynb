# %%
import herramientas_de_analisis_de_resultados as h
import numpy as np

# %%
p,v,mr,dt = h.cambio_a_pandas(r"C:\Users\rodri\Documents\Proyectos_Personales\choques\optimizado\dinamica.txt", 100)

# %%
p[(p['t'].isin([i for i in range(0,300)])) & (p['idx'].isin([89]))].plot.scatter(x = 'x', y='y')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
p[(p['t'].isin([232,233,234,235])) & (p['idx'].isin([89]))].plot.scatter(x = 'x', y='y')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
p[(p['t'].isin([i for i in range(0,100)])) & (p['idx'].isin([i for i in range(100)]))].plot.scatter(x = 'x', y='y')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
p[np.abs(p['idx'])==89]
# Out:
#        idx          x         y    t
# 89      89  30.000000  4.000000    0
# 186     89  29.974747  3.928283    1
# 286     89  29.949495  3.856566    2
# 386     89  29.928722  3.823393    3
# 486     89  29.934778  4.021095    4
# ...    ...        ...       ...  ...
# 29586   89  28.938359 -0.931097  295
# 29686   89  28.775700 -0.613818  296
# 29786   89  28.613041 -0.296538  297
# 29886   89  28.489888  0.013276  298
# 29986   89  28.701014  0.259927  299
#
# [300 rows x 4 columns]

# %%
p[np.abs(p['x'])>=52]
# Out:
# Empty DataFrame
# Columns: [idx, x, y, t]
# Index: []

# %%
p[np.abs(p['y'])>=7]
# Out:
#        idx          x         y    t
# 23290   89  39.185872  7.000883  232

# %%
p[p['idx']==0]
# Out:
#        idx          x         y    t
# 0        0 -50.000000 -5.000000    0
# 103      0 -49.986869 -5.015152    1
# 203      0 -49.973737 -5.030303    2
# 303      0 -49.960606 -5.045455    3
# 403      0 -49.947475 -5.060606    4
# ...    ...        ...       ...  ...
# 29513    0 -41.946196 -6.358610  295
# 29613    0 -41.847197 -6.392843  296
# 29713    0 -41.748198 -6.427076  297
# 29813    0 -41.649200 -6.461309  298
# 29914    0 -41.550201 -6.495542  299
#
# [300 rows x 4 columns]

# %%
len(mr['idx'].unique())
# Out:
# 100

# %%
mr
# Out:
#     idx         m    r
# 0     0  0.060606  0.3
# 1     1  0.888889  0.3
# 2     2  0.838384  0.3
# 3     3  0.474747  0.3
# 4     4  0.272727  0.3
# ..  ...       ...  ...
# 95   95  0.595960  0.3
# 96   96  0.848485  0.3
# 97   97  0.494949  0.3
# 98   98  0.434343  0.3
# 99   99  0.686869  0.3
#
# [100 rows x 3 columns]
