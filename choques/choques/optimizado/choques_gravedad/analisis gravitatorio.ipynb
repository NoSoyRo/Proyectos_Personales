# %%
import herramientas_de_analisis_de_resultados as h
import numpy as np

# %%
p,v,mr,dt = h.cambio_a_pandas(r"C:\Users\rodri\Documents\Proyectos_Personales\choques\choques\optimizado\choques_gravedad\dinamica.txt", 400)

# %%
p[(p['t'].isin([i for i in range(0,1000)])) & (p['idx'].isin([i for i in range(1)]))].plot.scatter(x = 'x', y='y')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
p[(p['idx'] == 0) & (p['t'].isin([i for i in range(50)]))].plot.scatter(x = 'x', y='y')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
v["magv"] = np.sqrt(v['vx']**2 + v['vy']**2)

# %%
v[v['t'] == 799].hist('magv', bins = 30)
# Out:
# array([[<AxesSubplot:title={'center':'magv'}>]], dtype=object)
